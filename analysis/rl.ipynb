# %%
import pandas as pd

df = pd.read_csv("datasets/pjm_wind_forecast_hourly_17feb_5march.csv")
df.head()
# Out:
#         interval_start_local         interval_start_utc  \
# 0  2026-02-17 00:00:00-05:00  2026-02-17 05:00:00+00:00
# 1  2026-02-17 01:00:00-05:00  2026-02-17 06:00:00+00:00
# 2  2026-02-17 02:00:00-05:00  2026-02-17 07:00:00+00:00
# 3  2026-02-17 03:00:00-05:00  2026-02-17 08:00:00+00:00
# 4  2026-02-17 04:00:00-05:00  2026-02-17 09:00:00+00:00
#
#           interval_end_local           interval_end_utc  \
# 0  2026-02-17 01:00:00-05:00  2026-02-17 06:00:00+00:00
# 1  2026-02-17 02:00:00-05:00  2026-02-17 07:00:00+00:00
# 2  2026-02-17 03:00:00-05:00  2026-02-17 08:00:00+00:00
# 3  2026-02-17 04:00:00-05:00  2026-02-17 09:00:00+00:00
# 4  2026-02-17 05:00:00-05:00  2026-02-17 10:00:00+00:00
#
#           publish_time_local           publish_time_utc  wind_forecast
# 0  2026-02-16 19:00:00-05:00  2026-02-17 00:00:00+00:00       6117.093
# 1  2026-02-16 20:00:00-05:00  2026-02-17 01:00:00+00:00       5792.992
# 2  2026-02-16 21:00:00-05:00  2026-02-17 02:00:00+00:00       5420.391
# 3  2026-02-16 22:00:00-05:00  2026-02-17 03:00:00+00:00       5041.463
# 4  2026-02-16 23:00:00-05:00  2026-02-17 04:00:00+00:00       4687.279

# %%
import matplotlib.pyplot as plt

# change these if your column names differ
time_col = "interval_start_local"   # or "timestamp", "time", etc.
y_col = "wind_forecast"

# make sure time is datetime and sort
df[time_col] = pd.to_datetime(df[time_col])
df = df.sort_values(time_col)

plt.figure(figsize=(12, 5))
plt.plot(df[time_col], df[y_col])
plt.xlabel(time_col)
plt.ylabel(y_col)
plt.title(f"{y_col} over time")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
